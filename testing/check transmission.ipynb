# %%
from rydanalysis import ExpSequence
from pathlib import Path
import xarray as xr

local_root= Path('/home/david/Institut/IEI-analysis/')
data_root= Path('/media/david/data')
seq_path= Path('2020_06_04/dDDSbluepro')
analysis_path = local_root/seq_path

# %%
data = xr.load_dataarray(analysis_path/'transmission.h5')

# %%
data[30].plot()
