# %%
from prefect import task
from rydanalysis import AbsorptionImaging, OldStructure, ExpSequence, ReferenceAnalysis, RectangularMask, EllipticalMask
from pathlib import Path

data_path = "/media/david/data/2020_06_04/dDDSbluepro"

# %%
seq = OldStructure(data_path)

# %%
images = seq.initialize_images()

# %%
images.image_01[0].plot()

# %%
tmstp_0 = seq.tmstps[4]
#images.shot.sel(tmstp=tmstp_0)
images.loc[dict(tmstp=tmstp_0)]
# Out:
# <xarray.Dataset>
# Dimensions:      (dDDSbluePro: 1, x: 100, y: 512)
# Coordinates:
#   * dDDSbluePro  (dDDSbluePro) float64 -42.0
#   * x            (x) float64 -211.9 -207.6 -203.3 -199.0 ... 203.3 207.6 211.9
#   * y            (y) float64 -1.094e+03 -1.089e+03 ... 1.089e+03 1.094e+03
# Data variables:
#     image_00     (dDDSbluePro, x, y) float32 nan nan nan nan ... nan nan nan nan
#     image_01     (dDDSbluePro, x, y) float32 nan nan nan nan ... nan nan nan nan
#     image_02     (dDDSbluePro, x, y) float32 nan nan nan nan ... nan nan nan nan
#     image_03     (dDDSbluePro, x, y) float32 nan nan nan nan ... nan nan nan nan
#     image_04     (dDDSbluePro, x, y) float32 nan nan nan nan ... nan nan nan nan
#     image_05     (dDDSbluePro, x, y) float32 nan nan nan nan ... nan nan nan nan
